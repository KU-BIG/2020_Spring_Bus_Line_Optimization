# %%
import matplotlib.pyplot as plt
import numpy as np

index = ['향남','봉담읍','동탄7동','동탄4동','동탄1동','매송면','서신면','마도면','비봉면','양감면']
male = [44242,39532,36509,26683,25757,3880,3938,4027,3285,2455]
female=[38870,38460,36013,27007,24644,3505,3153,2789,2564,1603]
alpha=0.5

p1 = plt.bar(index, male, color='b', alpha=alpha)
p2 = plt.bar(index, female, color='r', alpha=alpha, bottom=male)
plt.xticks(label, fontsize=15)
plt.legend((p1[0],p2[0]),('Male','Female'),fontsize=15)
plt.savefig ('hwaseongpop.png', dpi=200)
